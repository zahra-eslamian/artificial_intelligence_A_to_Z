# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-eslamian/artificial_intelligence_A_to_Z/blob/main/Fine_Tuning_LLMs_with_Hugging_Face_Medical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-Tuning LLMs with Hugging Face

# %% [markdown]
# ## Step 1: Installing and importing the libraries

# %%
# !pip uninstall accelerate peft bitsandbytes transformers trl -y
# !pip install accelerate peft==0.13.2 bitsandbytes transformers trl==0.12.0

# %%
# !pip install huggingface_hub

# %%
import torch
from trl import SFTTrainer
from peft import LoraConfig
from datasets import load_dataset
from transformers import (AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, pipeline)

# %% [markdown]
# ## Step 2: Loading the model

# %% [markdown]
# ## Step 3: Loading the tokenizer

# %% [markdown]
# ## Step 4: Setting the training arguments

# %% [markdown]
# ## Step 5: Creating the Supervised Fine-Tuning trainer

# %% [markdown]
# ## Step 6: Training the model

# %%
# Warning: To run the training you first need to sign up here: https://wandb.ai/authorize?ref=models
# And then you will directly find in the main page your API key which you will enter in the output below.

# %% [markdown]
# ## Step 7: Chatting with the model
